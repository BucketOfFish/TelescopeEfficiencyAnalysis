# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# /Users/mattzhang/py2_kernel/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
voltages = [40, 100, 160]
vec1000 = [84.50, 94.12, 98.57]
vec2000 = [60.62, 78.88, 98.41]
vec3000 = [43.16, 63.42, 95.14]

# %%
# W13-10
voltages = [0, 20, 60, 100, 140]
vec1000 = [89.71, 97.22, 97.46, 99.90, 99.93]
vec2000 = [37.08, 85.69, 97.07, 99.16, 99.67]
vec3000 = [42.95, 80.80, 93.62, 95.98]

# %%
# W13-10 - updated method (whole chip, pixel efficiencies above 60%)
voltages = [0, 20, 60, 100, 140]
vec1000 = [84.6757492804, 93.9241664206, 97.6566280946, 98.5081898278, 98.8132702491]
vec2000 = [67.9251681266, 84.5954276764, 92.1834195863, 93.2158948467, 94.3701719973]
vec3000 = [80.9050299178, 88.3499955030, 92.7455178209, 95.4061082031]

# %%
font22 = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 22}
font30 = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 30}
import matplotlib

# %%
line1000, = plt.plot(voltages, vec1000, 'bo-', ms=15, label='threshold 1000')
line2000, = plt.plot(voltages, vec2000,  'r^-', ms=15, label='threshold 2000')
line3000, = plt.plot(voltages[1:], vec3000, 'g*-',  ms=20, label='threshold 3000')
plt.legend(handles=[line1000, line2000, line3000], loc=4)
plt.xlim([0,200]);
plt.ylim([0,100]);
plt.title("Track Reconstruction Efficiency vs. Threshold and HV", fontsize=40, y=1.08);
plt.xlabel("Bias Voltage (V)", fontsize=30, labelpad=20);
plt.ylabel("Track Reconstruction Efficiency (%))", fontsize=30);
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
ax = fig.add_subplot(111)
plt.subplots_adjust(top=0.85)
ax.annotate('Geneva Telescope - Fermilab 2017 (120 GeV protons)\nH35DEMO W13-10, 200 Ohm*cm , 750 um thickness\nsub matrix of ANA1, col. 29-39, row 175-200', xy=(2, 1), xytext=(80, 50), fontsize=22)
plt.savefig("Blah.png")
